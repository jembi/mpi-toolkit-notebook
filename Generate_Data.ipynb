# %% [markdown]
# <a href="https://colab.research.google.com/github/jembi/mpi-toolkit-notebook/blob/main/Generate_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📝 <font color="red">NOTE: Please do not execute a run all command.

# %% [markdown]
# #**<font color="#007f68">Dataset Generator**
#
# Research and development of novel techniques in areas such as data mining and record linkage commonly require real-world data for testing and evaluation of the accuracy, efficiency and effectiveness of these techniques. In areas and applications where the data include personal information, it is often difficult to acquire real data due to privacy and confidentiality concerns [2].
#
# An alternative to using real data is to generate synthetic (or artificial) data which is based on real data [1, 5]. Such gen- erated data should exhibit similar statistical characteristics compared to the real data they are based on. For example, the generated values, their frequency distributions, and the occurrences and frequencies of typographical and other errors and variations should follow real data. Dependencies between elements of real data should also be modelled.
#
# The methodological advantages of synthetic data are that [1, 5] (a) they can be generated with well defined frequency distributions, error characteristics and variations; (b) the status of which records have been generated based on each other is known, allowing for example to measure the accuracy of matching records when synthetic data are used for record linkage (generally not possible on real data because true matches are unknown); and (c) the generated data, as well as the generator program itself, can be published.
#
# This section is optional, you can edit varibales to alter the output of the data-generator.

# %% [markdown]
# ## <font color="#007f68"> Links
#
# [Directory Notebook](https://colab.research.google.com/drive/1TqQ5sklvhw8I1f5m49ob-WTFfBtiElfs#scrollTo=M5NmyYErfDvt)
#
# [Blocking Notebook](https://colab.research.google.com/drive/1fB6pa8Xu1cMdf1VmnTZ7bn5j-TS_ccRO#scrollTo=cbBPp8a-1ou5&forceEdit=true&sandboxMode=true)

# %% [markdown]
# ## **<font color="#007f68">1) Notebook setup**

# %%
#@title <font color="#18CF68">Clone the github Data Generator Repo from Github
# !git clone https://github.com/jembi/mpi-toolkit-notebook.git
# Out:
# Cloning into 'mpi-toolkit-notebook'...
# remote: Enumerating objects: 248, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (214/214), done.
# remote: Total 248 (delta 119), reused 82 (delta 28), pack-reused 0
# Receiving objects: 100% (248/248), 801.35 KiB | 5.45 MiB/s, done.
# Resolving deltas: 100% (119/119), done.

# %%
#@title <font color="#18CF68"> Initial imports
import pandas as pd
import os
import sys
import shutil
import ipywidgets as widgets
from PIL import Image
from google.colab import files
import ipywidgets as widgets
from ipywidgets import HBox, VBox, Dropdown, Button, FloatSlider, IntSlider, IntText, FloatText
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %%
#@title <font color="#18CF68"> Set up Variables

#Probability Distribution for Attributes
given_name_val= 0.3
family_name_val= 0.1
gender_val=0.2
dob_val=0.1
city_val=0.1
pn_val=0.1
nid_val=0.1

# Data Generator parameters 
max_duplicate_per_record =  2 

num_duplicates_distribution = 'zipf' 

max_modification_per_attr = 1 

num_modification_per_record = 4 

#Given Name Corruptor

missing_val_FN = 0.1 
name_misspell_FN = 0.1 
edit_FN = 0.1 
ocr_FN = 0.1 
keyboard_FN = 0.1 
phonetic_FN = 0.5 

#Family Name Corruptor

missing_val_LN = 0.1 
name_misspell_LN = 0.1 
edit_LN = 0.1 
ocr_LN = 0.1 
keyboard_LN = 0.1 
phonetic_LN = 0.5 

#Gender at Birth Corruptor

missing_val_GAB = 0.2 
ocr_GAB = 0.4 
keyboard_GAB = 0.4

#Date of Birth Corruptor

missing_val_DOB = 0.5 
keyboard_DOB = 0.5 

#City Corruptor

missing_val_C = 0.2 
edit_C = 0.4 
phonetic_C = 0.4 


#Phone Number Corruptor

missing_val_PN = 0.2 
edit_PN = 0.4 
keyboard_PN = 0.4

#National ID Corruptor

missing_val_NID = 0.4 
ocr_NID = 0.2 
keyboard_NID = 0.4 

number_of_originals =  1000 
number_of_duplicates =  500

# %% [markdown]
# ### <font color="#007f68"> Download Manual [OPTIONAL]

# %%
#@title <font color="#18CF68"> Download Manual
files.download("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/flex-data-gen-manual.pdf")

# %% [markdown]
# ### <font color="#007f68"> Mount your own google drive [OPTIONAL]
#
# This step is optional, you can mount your own google drive so that the generated dataset can be saved there.
#
# Follow the link to get authorisation code.

# %%
#@title <font color="#18CF68"> Mount Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **<font color="#007f68">2) Modify Variables [OPTIONAL]**
#
# This section is optional, you can edit varibales to alter the output of the data-generator.

# %% [markdown]
# ### <font color="#007f68"> Set Up Variables

# %% [markdown]
# Change values below to your desired position and then click the Update button to set changes.
#
# To reset the values to the default click the Reset button.

# %% [markdown]
# **Max duplicate per record (MDPR)**
#
# **Duplicates Distribution (DD)**
#
# **Max modification per attr (MMPA)**
#
# **Number of modifications per record (NMPR)**

# %%
#@title <font color="#18CF68">Data Generator Parameters


max_duplicate_per_record =  2 

num_duplicates_distribution = 'zipf' 

max_modification_per_attr = 1 

num_modification_per_record = 4 

max_duplicate_per_record_slider = IntSlider(description="MDPR", value=max_duplicate_per_record, min=0, max=10, step=1, disabled=False)

num_duplicates_distribution_drop = Dropdown(description="DD", value=num_duplicates_distribution, options=["zipf", "poisson", "uniform"], disabled=False)

max_modification_per_attr_slider = IntSlider(description="MMPA", value=max_modification_per_attr, min=0, max=10, step=1, disabled=False)

num_modification_per_record_slider = IntSlider(description="NMPR", value=num_modification_per_record, min=0, max=100, step=1, disabled=False)

reset_button = Button(description="Reset", disabled=False)
def default_values(*args):

    # set values to default
    global max_duplicate_per_record 
    global num_duplicates_distribution 
    global max_modification_per_attr 
    global num_modification_per_record 
    max_duplicate_per_record =  2 
    num_duplicates_distribution = 'zipf' 
    max_modification_per_attr = 1 
    num_modification_per_record = 4 
    max_duplicate_per_record_slider.value =  2 
    num_duplicates_distribution_drop.value = 'zipf' 
    max_modification_per_attr_slider.value = 1 
    num_modification_per_record_slider.value = 4 

    print("Your choice is : ",max_duplicate_per_record_slider.value , num_duplicates_distribution_drop.value, max_modification_per_attr_slider.value, num_modification_per_record_slider.value )


reset_button.on_click(default_values)

update_button = Button(description="Update", disabled=False)
def update_values(*args):

    # set values to default
    global max_duplicate_per_record 
    global num_duplicates_distribution 
    global max_modification_per_attr 
    global num_modification_per_record
    max_duplicate_per_record =  max_duplicate_per_record_slider.value
    num_duplicates_distribution = num_duplicates_distribution_drop.value
    max_modification_per_attr = max_modification_per_attr_slider.value
    num_modification_per_record = num_modification_per_record_slider.value

    print("Your choice is : ", max_duplicate_per_record_slider.value , num_duplicates_distribution_drop.value, max_modification_per_attr_slider.value, num_modification_per_record_slider.value )


update_button.on_click(update_values)


VBox([max_duplicate_per_record_slider, num_duplicates_distribution_drop, max_modification_per_attr_slider, num_modification_per_record_slider, update_button, reset_button])
# Out:
# VBox(children=(IntSlider(value=2, description='MDPR', max=10), Dropdown(description='DD', options=('zipf', 'po…

# %% [markdown]
# Set how many original and how many duplicate records are to be generated.
#
# *This is optimised when the number of duplicates is half or less of the number of originals.*

# %%
#@title <font color="#18CF68">Records

number_of_originals =  1000 
number_of_duplicates =  500

number_of_originals_slider = IntSlider(description="Originals", value=number_of_originals, min=0, max=30000, step=50, disabled=False)
number_of_duplicates_slider = IntSlider(description="Duplicates", value=number_of_duplicates, min=0, max=15000, step=25, disabled=False)


reset_button = Button(description="Reset", disabled=False)

def check_max_dup(*args):
  if(number_of_originals_slider.value==0):
    max_bool=True
    print("Originals cannot be zero")
  else:
    x = (number_of_duplicates_slider.value/number_of_originals_slider.value)
    if(x > max_duplicate_per_record):
      print("Maximum Duplicates Exceeded")
      max_bool = True
    else:
      max_bool = False
        
  update_button.disabled=max_bool



def default_values(*args):

    # set values to default
    global number_of_originals
    global number_of_duplicates
    number_of_originals =  1000 
    number_of_duplicates =  500
    number_of_originals_slider.value  =  1000 
    number_of_duplicates_slider.value  =  500

    print(number_of_originals, number_of_duplicates)


reset_button.on_click(default_values)

update_button = Button(description="Update", disabled=False)
def update_values(*args):

    # set values to default
    global number_of_originals
    global number_of_duplicates
    number_of_originals =  number_of_originals_slider.value
    number_of_duplicates = number_of_duplicates_slider.value
    print(number_of_originals, number_of_duplicates)

update_button.on_click(update_values)
number_of_originals_slider.observe(check_max_dup, 'value')
number_of_duplicates_slider.observe(check_max_dup, 'value')

VBox([number_of_originals_slider, number_of_duplicates_slider, update_button, reset_button])
# Out:
# VBox(children=(IntSlider(value=1000, description='Originals', max=30000, step=50), IntSlider(value=500, descri…
# Originals cannot be zero
# Originals cannot be zero
# Maximum Duplicates Exceeded
# Maximum Duplicates Exceeded
# Maximum Duplicates Exceeded
# 1000 500
# 1000 500

# %% [markdown]
# Define the probability distribution of how likely an attribute will be selected for a modification.
#
# Each of the given probability values must be between 0 and 1, and the sum of them must be 1.0 otherwise "Update" button will. not work.
#
# If a probability is set to 0 for a certain attribute, then no modification will be applied on this attribute.
#
# Change values below to your desired position and then click the Update button to set changes.
#
# To reset the values to the default click the Reset button.

# %%
#@title <font color="#18CF68">Modification probability distribution
# establish important values for later use
given_name_val= 0.3
family_name_val= 0.1
gender_val=0.2
dob_val=0.1
city_val=0.1
pn_val=0.1
nid_val=0.1

# create the 6 individual sliders
given_name_val_slider = FloatSlider(description="Given Name", value=given_name_val, min=0, max=1, step=0.01)
family_name_val_slider = FloatSlider(description="Family Name", value=family_name_val, min=0, max=1, step=0.01)
gender_val_slider = FloatSlider(description="Gender", value=gender_val, min=0, max=1, step=0.01)
dob_val_slider = FloatSlider(description="Date of Birth", value=dob_val, min=0, max=1, step=0.01)
city_val_slider = FloatSlider(description="City", value=city_val, min=0, max=1, step=0.01)
pn_val_slider = FloatSlider(description="Phone Number", value=pn_val, min=0, max=1, step=0.01)
nid_val_slider = FloatSlider(description="National ID", value=nid_val, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (given_name_val_slider.value + family_name_val_slider.value + gender_val_slider.value + dob_val_slider.value + city_val_slider.value + pn_val_slider.value + nid_val_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global given_name_val
    global family_name_val
    global gender_val
    global dob_val
    global city_val
    global pn_val
    global nid_val
    given_name_val= 0.22
    family_name_val= 0.16
    gender_val=0.08
    dob_val=0.19
    city_val=0.09
    pn_val=0.07
    nid_val=0.19
    given_name_val_slider.value = given_name_val
    family_name_val_slider.value = family_name_val
    gender_val_slider.value = gender_val
    dob_val_slider.value = dob_val
    city_val_slider.value = city_val
    pn_val_slider.value = pn_val 
    nid_val_slider.value = nid_val

    print(given_name_val, family_name_val, gender_val, dob_val, city_val, pn_val, nid_val)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global given_name_val
    global family_name_val
    global gender_val
    global dob_val
    global city_val
    global pn_val
    global nid_val
    given_name_val = given_name_val_slider.value
    family_name_val = family_name_val_slider.value
    gender_val = gender_val_slider.value
    dob_val = dob_val_slider.value
    city_val = city_val_slider.value
    pn_val = pn_val_slider.value
    nid_val_FN = nid_val_slider.value

    print(given_name_val, family_name_val, gender_val, dob_val, city_val, pn_val, nid_val)

# when slider or button is interacted with
update_button.on_click(update_values)

given_name_val_slider.observe(check_sum, 'value')
family_name_val_slider.observe(check_sum, 'value')
gender_val_slider.observe(check_sum, 'value')
dob_val_slider.observe(check_sum, 'value')
city_val_slider.observe(check_sum, 'value')
pn_val_slider.observe(check_sum, 'value')
nid_val_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([given_name_val_slider, family_name_val_slider, gender_val_slider, 
      dob_val_slider, city_val_slider, pn_val_slider, nid_val_slider, 
      total_box, 
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.3, description='Given Name', max=1.0), FloatSlider(value=0.1, description='…

# %% [markdown]
# ### <font color="#007f68"> Corruptors

# %% [markdown]
# Define the actual corruption (modification) methods that will be applied on the different attributes, then click the "Update" button to set changes.
#
# For each attribute, the sum of probabilities given must sum to 1.0 otherwise the "Update" button will not work.
#
# To reset the values to the default click the Reset button.

# %% [markdown]
# Types of errors:
#
# **Missing Value (MV) - Empty identifiers.**
#
# **Name Misspell (MV)- Example - use of nicknames instead of real names.**
#
# **Edit - Wrong use of special characters and spaces**
#
# **Optical Character Recognition (OCR) - The use of scanners to capture data often introduces errors.**
#
# **Keyboard - transposition of keys and characters**
#
# **Phonetic - Spelling errors when entering names because of phonetic interpretations.**

# %%
#@title <font color="#18CF68">Given Name Corruptor

# establish important values for later use
missing_val_FN, name_misspell_FN, edit_FN, ocr_FN, keyboard_FN, phonetic_FN = 0.1, 0.1, 0.2, 0.1, 0.2, 0.3

# create the 6 individual sliders
missing_val_FN_slider = FloatSlider(description="MV", value=missing_val_FN, min=0, max=1, step=0.01)
name_misspell_FN_slider = FloatSlider(description="NM", value=name_misspell_FN, min=0, max=1, step=0.01)
edit_FN_slider = FloatSlider(description="Edit", value=edit_FN, min=0, max=1, step=0.01)
ocr_FN_slider = FloatSlider(description="OCR", value=ocr_FN, min=0, max=1, step=0.01)
keyboard_FN_slider = FloatSlider(description="Keyboard", value=keyboard_FN, min=0, max=1, step=0.01)
phonetic_FN_slider = FloatSlider(description="Phonetic", value=phonetic_FN, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_FN_slider.value + name_misspell_FN_slider.value + 
             edit_FN_slider.value + ocr_FN_slider.value + 
             keyboard_FN_slider.value + phonetic_FN_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_FN 
    global name_misspell_FN
    global edit_FN
    global ocr_FN
    global keyboard_FN
    global phonetic_FN
    missing_val_FN, name_misspell_FN, edit_FN, ocr_FN, keyboard_FN, phonetic_FN = 0.1, 0.1, 0.2, 0.1, 0.2, 0.3
    missing_val_FN_slider.value = missing_val_FN 
    name_misspell_FN_slider.value = name_misspell_FN 
    edit_FN_slider.value = edit_FN  
    ocr_FN_slider.value = ocr_FN  
    keyboard_FN_slider.value = keyboard_FN  
    phonetic_FN_slider.value = phonetic_FN  

    print(missing_val_FN, name_misspell_FN, edit_FN, ocr_FN, keyboard_FN, phonetic_FN)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_FN 
    global name_misspell_FN
    global edit_FN
    global ocr_FN
    global keyboard_FN
    global phonetic_FN
    missing_val_FN = missing_val_FN_slider.value
    name_misspell_FN = name_misspell_FN_slider.value
    edit_FN = edit_FN_slider.value
    ocr_FN = ocr_FN_slider.value
    keyboard_FN = keyboard_FN_slider.value
    phonetic_FN = phonetic_FN_slider.value

    print(missing_val_FN, name_misspell_FN, edit_FN, ocr_FN, keyboard_FN, phonetic_FN)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_FN_slider.observe(check_sum, 'value')
name_misspell_FN_slider.observe(check_sum, 'value')
edit_FN_slider.observe(check_sum, 'value')
ocr_FN_slider.observe(check_sum, 'value')
keyboard_FN_slider.observe(check_sum, 'value')
phonetic_FN_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_FN_slider, name_misspell_FN_slider, edit_FN_slider, 
      ocr_FN_slider, keyboard_FN_slider, phonetic_FN_slider, 
      total_box, 
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.1, description='MV', max=1.0, step=0.01), FloatSlider(value=0.1, descriptio…

# %%
#@title <font color="#18CF68">Family Name Corruptor


# establish important values for later use
missing_val_LN, name_misspell_LN, edit_LN, ocr_LN, keyboard_LN, phonetic_LN = 0.1, 0.1, 0.2, 0.1, 0.2, 0.3

# create the 6 individual sliders
missing_val_LN_slider = FloatSlider(description="MV", value=missing_val_LN, min=0, max=1, step=0.01)
name_misspell_LN_slider = FloatSlider(description="NM", value=name_misspell_LN, min=0, max=1, step=0.01)
edit_LN_slider = FloatSlider(description="Edit", value=edit_LN, min=0, max=1, step=0.01)
ocr_LN_slider = FloatSlider(description="OCR", value=ocr_LN, min=0, max=1, step=0.01)
keyboard_LN_slider = FloatSlider(description="Keyboard", value=keyboard_LN, min=0, max=1, step=0.01)
phonetic_LN_slider = FloatSlider(description="Phonetic", value=phonetic_LN, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_LN_slider.value + name_misspell_LN_slider.value + 
             edit_LN_slider.value + ocr_LN_slider.value + 
             keyboard_LN_slider.value + phonetic_LN_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_LN 
    global name_misspell_LN
    global edit_LN
    global ocr_LN
    global keyboard_LN
    global phonetic_LN
    missing_val_LN, name_misspell_LN, edit_LN, ocr_LN, keyboard_LN, phonetic_LN = 0.1, 0.1, 0.2, 0.1, 0.2, 0.3
    missing_val_LN_slider.value = missing_val_LN 
    name_misspell_LN_slider.value = name_misspell_LN 
    edit_LN_slider.value = edit_LN  
    ocr_LN_slider.value = ocr_LN  
    keyboard_LN_slider.value = keyboard_LN  
    phonetic_LN_slider.value = phonetic_LN  

    print(missing_val_LN, name_misspell_LN, edit_LN, ocr_LN, keyboard_LN, phonetic_LN)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_LN 
    global name_misspell_LN
    global edit_LN
    global ocr_LN
    global keyboard_LN
    global phonetic_LN
    missing_val_LN = missing_val_LN_slider.value
    name_misspell_LN = name_misspell_LN_slider.value
    edit_LN = edit_LN_slider.value
    ocr_LN = ocr_LN_slider.value
    keyboard_LN = keyboard_LN_slider.value
    phonetic_LN = phonetic_LN_slider.value

    print(missing_val_LN, name_misspell_LN, edit_LN, ocr_LN, keyboard_LN, phonetic_LN)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_LN_slider.observe(check_sum, 'value')
name_misspell_LN_slider.observe(check_sum, 'value')
edit_LN_slider.observe(check_sum, 'value')
ocr_LN_slider.observe(check_sum, 'value')
keyboard_LN_slider.observe(check_sum, 'value')
phonetic_LN_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_LN_slider, name_misspell_LN_slider, edit_LN_slider, 
      ocr_LN_slider, keyboard_LN_slider, phonetic_LN_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.1, description='MV', max=1.0, step=0.01), FloatSlider(value=0.1, descriptio…

# %%
#@title <font color="#18CF68">Gender at Birth Corruptor

# establish important values for later use
missing_val_GAB = 0.2 
ocr_GAB = 0.4 
keyboard_GAB = 0.4


# create the 6 individual sliders
missing_val_GAB_slider = FloatSlider(description="MV", value=missing_val_GAB, min=0, max=1, step=0.01)
ocr_GAB_slider = FloatSlider(description="Edit", value=ocr_GAB, min=0, max=1, step=0.01)
keyboard_GAB_slider = FloatSlider(description="Keyboard", value=keyboard_GAB, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_GAB_slider.value + ocr_GAB_slider.value + 
             keyboard_GAB_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_GAB 
    global ocr_GAB 
    global keyboard_GAB 
    missing_val_GAB = 0.2 
    ocr_GAB = 0.4 
    keyboard_GAB = 0.4
    missing_val_GAB_slider.value = missing_val_GAB 
    ocr_GAB_slider.value = ocr_GAB  
    keyboard_GAB_slider.value = keyboard_GAB  

    print(missing_val_GAB, ocr_GAB, keyboard_GAB)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_GAB 
    global ocr_GAB 
    global keyboard_GAB 
    missing_val_GAB = missing_val_GAB_slider.value
    ocr_GAB = ocr_GAB_slider.value
    keyboard_GAB = keyboard_GAB_slider.value

    print(missing_val_GAB, ocr_GAB, keyboard_GAB)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_GAB_slider.observe(check_sum, 'value')
ocr_GAB_slider.observe(check_sum, 'value')
keyboard_GAB_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_GAB_slider, ocr_GAB_slider, keyboard_GAB_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.2, description='MV', max=1.0, step=0.01), FloatSlider(value=0.4, descriptio…

# %%
#@title <font color="#18CF68">Date of Birth

# establish important values for later use

missing_val_DOB = 0.5 
keyboard_DOB = 0.5 


# create the 6 individual sliders
missing_val_DOB_slider = FloatSlider(description="MV", value=missing_val_DOB, min=0, max=1, step=0.01)
keyboard_DOB_slider = FloatSlider(description="Keyboard", value=keyboard_DOB, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_DOB_slider.value + keyboard_DOB_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_DOB
    global keyboard_DOB 
    missing_val_DOB = 0.5 
    keyboard_DOB = 0.5 
    missing_val_DOB_slider.value = missing_val_DOB
    keyboard_DOB_slider.value = keyboard_DOB  

    print(missing_val_DOB, keyboard_DOB)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_DOB
    global keyboard_DOB 
    missing_val_DOB = missing_val_DOB_slider.value
    keyboard_GAB = keyboard_GAB_slider.value

    print(missing_val_DOB, keyboard_DOB)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_DOB_slider.observe(check_sum, 'value')
keyboard_DOB_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_DOB_slider, keyboard_DOB_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.5, description='MV', max=1.0, step=0.01), FloatSlider(value=0.5, descriptio…

# %%
#@title <font color="#18CF68">City Corruptor

# establish important values for later use
missing_val_C = 0.2 
edit_C = 0.4 
phonetic_C = 0.4 


# create the 6 individual sliders
missing_val_C_slider = FloatSlider(description="MV", value=missing_val_C, min=0, max=1, step=0.01)
edit_C_slider = FloatSlider(description="Edit", value=edit_C, min=0, max=1, step=0.01)
phonetic_C_slider = FloatSlider(description="Phonetic", value=phonetic_C, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_C_slider.value + edit_C_slider.value + 
             phonetic_C_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_C 
    global edit_C 
    global phonetic_C
    missing_val_C = 0.2 
    edit_C = 0.4 
    phonetic_C = 0.4
    missing_val_C_slider.value = missing_val_C 
    edit_C_slider.value = edit_C  
    phonetic_C_slider.value = phonetic_C  

    print(missing_val_C, edit_C, phonetic_C)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_C 
    global edit_C 
    global phonetic_C
    missing_val_C = missing_val_C_slider.value
    edit_C = edit_C_slider.value
    phonetic_C = phonetic_C_slider.value

    print(missing_val_C, edit_C, phonetic_C)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_C_slider.observe(check_sum, 'value')
edit_C_slider.observe(check_sum, 'value')
phonetic_C_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_C_slider, edit_C_slider, phonetic_C_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.2, description='MV', max=1.0, step=0.01), FloatSlider(value=0.4, descriptio…

# %%
#@title <font color="#18CF68">Phone Number Corruptor

# establish important values for later use
missing_val_PN = 0.2 
edit_PN = 0.4 
keyboard_PN = 0.4


# create the 6 individual sliders
missing_val_PN_slider = FloatSlider(description="MV", value=missing_val_PN, min=0, max=1, step=0.01)
edit_PN_slider = FloatSlider(description="Edit", value=edit_PN, min=0, max=1, step=0.01)
keyboard_PN_slider = FloatSlider(description="Keyboard", value=keyboard_PN, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_PN_slider.value + edit_PN_slider.value + 
             keyboard_PN_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_PN 
    global edit_PN
    global keyboard_PN
    missing_val_PN = 0.2 
    edit_PN = 0.4 
    keyboard_PN = 0.4
    missing_val_PN_slider.value = missing_val_PN 
    edit_PN_slider.value = edit_PN  
    keyboard_PN_slider.value = keyboard_PN  

    print(missing_val_PN, edit_PN, keyboard_PN)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_PN 
    global edit_PN
    global keyboard_PN
    missing_val_PN = missing_val_PN_slider.value
    edit_PN = edit_PN_slider.value
    keyboard_PN = keyboard_PN_slider.value

    print(missing_val_PN, edit_PN, keyboard_PN)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_PN_slider.observe(check_sum, 'value')
edit_PN_slider.observe(check_sum, 'value')
keyboard_PN_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_PN_slider, edit_PN_slider, keyboard_PN_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.2, description='MV', max=1.0, step=0.01), FloatSlider(value=0.4, descriptio…

# %%
#@title <font color="#18CF68">National ID

# establish important values for later use
missing_val_NID = 0.4 
ocr_NID = 0.2 
keyboard_NID = 0.4


# create the 6 individual sliders
missing_val_NID_slider = FloatSlider(description="MV", value=missing_val_NID, min=0, max=1, step=0.01)
ocr_NID_slider = FloatSlider(description="Edit", value=ocr_NID, min=0, max=1, step=0.01)
keyboard_NID_slider = FloatSlider(description="Keyboard", value=keyboard_NID, min=0, max=1, step=0.01)

# total
total_slider = FloatSlider(description="Sum total", value=1, min=0, max=5, step=0.1, disabled=True)
total_box= FloatText(description="Sum total", continuous_update=True, disabled=True)
widgets.link((total_slider, 'value'), (total_box, 'value'))

# this button will update the important variables only when the sum of those variables equal to 1
update_button = Button(description="Update", disabled=False)
reset_button = Button(description="Reset", disabled=False)

def check_sum(*args):

    total = (missing_val_NID_slider.value + ocr_NID_slider.value + 
             keyboard_NID_slider.value)
    total_slider.value=total
    total_bool = (total != 1)
    update_button.disabled=total_bool       # once all the values sum to 1, the update button is enabled

def default_values(*args):

    # set values to default
    global missing_val_NID
    global ocr_NID 
    global keyboard_NID
    missing_val_NID = 0.2 
    ocr_NID = 0.4 
    keyboard_NID = 0.4
    missing_val_NID_slider.value = missing_val_NID 
    ocr_NID_slider.value = ocr_NID  
    keyboard_NID_slider.value = keyboard_NID  

    print(missing_val_NID, ocr_NID, keyboard_NID)

#reset values when clickd
reset_button.on_click(default_values)

def update_values(*args):

    # update the values
    global missing_val_NID
    global ocr_NID 
    global keyboard_NID
    missing_val_NID = missing_val_NID_slider.value
    ocr_NID = ocr_NID_slider.value
    keyboard_NID = keyboard_NID_slider.value

    print(missing_val_NID, ocr_NID, keyboard_NID)

# when slider or button is interacted with
update_button.on_click(update_values)

missing_val_NID_slider.observe(check_sum, 'value')
ocr_NID_slider.observe(check_sum, 'value')
keyboard_NID_slider.observe(check_sum, 'value')

# display vertically, not sure how to present the entire description of each slider
VBox([missing_val_NID_slider, ocr_NID_slider, keyboard_NID_slider, total_box,
      update_button, reset_button])
# Out:
# VBox(children=(FloatSlider(value=0.4, description='MV', max=1.0, step=0.01), FloatSlider(value=0.2, descriptio…

# %% [markdown]
# ## **<font color="#007f68">3) Data Generation Configuration [OPTIONAL]**
#
# This section is optional, you can view, download and update Frequency Distribution Files.

# %% [markdown]
# ###<font color="#007f68">View Frequency Distribution Files

# %% [markdown]
# This sections allows you to view the current lookup tables and replace then with your own csv files

# %%
#@title <font color="#18CF68">Display City Frequency
city_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/city-freq.csv", header=None)
display(city_freq)
# Out:
#                 0   1
# 0         Nairobi  28
# 1         Mombasa   8
# 2          Kisumu   5
# 3          Nakuru   4
# 4           Ruiru   3
# ..            ...  ..
# 98   Burnt Forest   1
# 99        Maragua   1
# 100     Kendu Bay   1
# 101          Ruai   1
# 102        Kamulu   1
#
# [103 rows x 2 columns]

# %%
#@title <font color="#18CF68">Display Given Name & Gender Frequency
name_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-gender-freq.csv", header=None)
display(name_freq)
# Out:
#               0   1     2    3       4    5
# 0          John  75  Male  100  Female    1
# 1        Joseph  69  Male  100  Female    1
# 2          Mary  68  Male    1  Female  100
# 3         Faith  67  Male    1  Female  100
# 4         Mercy  67  Male    1  Female  100
# ...         ...  ..   ...  ...     ...  ...
# 996   Abdisalam   1  Male   50  Female   50
# 997        Deka   1  Male   50  Female   50
# 998       Ivone   1  Male    1  Female  100
# 999        Hawo   1  Male   50  Female   50
# 1000       Oloo   1  Male   53  Female   47
#
# [1001 rows x 6 columns]

# %%
#@title <font color="#18CF68">Display Family Name Frequency
name_m_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/family-name-freq.csv", header=None)
display(name_m_freq)
# Out:
#             0   1
# 0      Otieno  90
# 1     Mohamed  81
# 2      Mwangi  78
# 3    Odhiambo  57
# 4       Maina  57
# ..        ...  ..
# 995     Kevin   1
# 996    Omweri   1
# 997  Maghanga   1
# 998    Nafuna   1
# 999  Angwenyi   1
#
# [1000 rows x 2 columns]

# %% [markdown]
# ###<font color="#007f68"> Download Frequency Distribution Files

# %%
#@title <font color="#18CF68">Download City Frequency file
files.download("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/city-freq.csv")

# %%
#@title <font color="#18CF68">Download Given Name Frequency file
files.download("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-gender-freq.csv")

# %%
#@title <font color="#18CF68">Download Family Name Frequency file
files.download("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/family-name-freq.csv")

# %% [markdown]
# ###<font color="#007f68"> Update Frequency Distribution Files
# ⚠️ <font color="red">*WARNING! DO NOT RUN IF YOU ARE NOT CHANGING CSV FILES* ⚠️

# %% [markdown]
# Upload the frequency CSV files you want to use. This will replace the original files with the ones you upload.

# %% [markdown]
#     The format of the City Name Frequency file is:
#      # Comment lines start with the # character
#      (Repeated city names will cause errors)
#
#      The look-up file is a comma separated values (CSV) file which contains
#      one type of row:
#      Example:
#       City_1,70
#       City_2,10
#       City_3,5
#       City_4,10
#       City_5,5
#       ...

# %%
#@title <font color="#18CF68">Upload City Name Frequency file
uploadCF = files.upload()

x =uploadCF.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

os.rename(z , "/content/city-freq.csv")

! rm "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/city-freq.csv"

shutil.move("/content/city-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
#      The format of the Given Name & Gender Frequency file is:
#      # Comment lines start with the # character
#      (Repeated female or male names will cause errors)
#
#      Example:
#       F_Name_1,8,female,1
#       F_Name_2,7,female,1
#       F_Name_3,7,female,1
#       F_Name_4,7,female,1
#       F_Name_5,6,female,1
#       ...
#       M_Name_1,26,male,1
#       M_Name_2,26,male,1
#       M_Name_3,23,male,1
#       M_Name_4,21,male,1
#       ...

# %%
#@title <font color="#18CF68">Upload Given Name & Gender Frequency file
uploadFN = files.upload()

x =uploadFN.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

os.rename(z , "/content/given-name-gender-freq.csv")

! rm "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-gender-freq.csv"

shutil.move("/content/given-name-gender-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
#     The format of the Family Name Frequency file is:
#      # Comment lines start with the # character
#      (Repeated family names will cause errors)
#
#      The look-up file is a comma separated values (CSV) file which contains
#      one type of row:
#      Example:
#       Family_Name_1,26
#       Family_Name_2,26
#       Family_Name_3,23
#       Family_Name_4,21
#       Family_Name_5,20
#
#       ...

# %%
#@title <font color="#18CF68">Upload Family Name Frequency file
uploadLN = files.upload()

x =uploadLN.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

os.rename(z , "/content/family-name-freq.csv")

! rm "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/family-name-freq.csv"

shutil.move("/content/family-name-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
# ## **<font color="#007f68"> 4) Generate Data**

# %% [markdown]
# ### <font color="#007f68">Create file path to allow for imports and import necessary classes

# %%
#@title <font color="#18CF68">Create file path
py_file_location = "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya"
sys.path.append(os.path.abspath(py_file_location))

# %%
#@title <font color="#18CF68">Import Classes
import random

import attrgenfunct  # Functions to generate independent attribute values
# Import the necessary other modules of the data generator
#
import basefunctions  # Helper functions
import corruptor  # Main classes to corrupt attribute values and records
import generator  # Main classes to generate records and the data set
import output       # Main classes to output logs to a .txt file

random.seed(42)  # Set seed for random generator, so data generation can
#                       be repeated

# %% [markdown]
# ### <font color="#007f68"> Run the Data Generator & View Results

# %%
#@title <font color="#18CF68">Run Data Generator

output.create_file()


ATTR_NAME = "Given Name"  # IN
ATTR_LAST_NAME = "Family Name"  # IN
ATTR_GENDER = "Gender at Birth"  # IN
ATTR_DOB = "Date of Birth"  # IN
ATTR_CITY = "City"  # IN
ATTR_PHONE_NUMBER = "Phone Number"  # IN [optional]
ATTR_NATIONAL_ID = "National ID"  # IN [optional]

# Set the Unicode encoding for this data generation project. This needs to be
# changed to another encoding for different Unicode character sets.
# Valid encoding strings are listed here:
# http://docs.python.org/library/codecs.html#standard-encodings
#
unicode_encoding_used = 'utf_8'

# ascii was used previouisly but caused encoding errors 

# The name of the record identifier attribute (unique value for each record).
# This name cannot be given as name to any other attribute that is generated.
#
rec_id_attr_name = 'ID'

# Set how many original and how many duplicate records are to be generated.
#

num_org_rec = int(number_of_originals)
num_dup_rec = int(number_of_duplicates)

# Set the file name of the data set to be generated (this will be a comma
# separated values, CSV, file).
#
out_file_name = 'data-{}-{}.csv'.format(num_org_rec, num_dup_rec)



# Check if the given the unicode encoding selected is valid.
#
basefunctions.check_unicode_encoding_exists(unicode_encoding_used)

# -----------------------------------------------------------------------------
# Define the attributes to be generated (using methods from the generator.py
# module).
#


name_gender_attr = \
    generator.GenerateCateCateCompoundAttribute(
        categorical1_attribute_name=ATTR_NAME,
        categorical2_attribute_name=ATTR_GENDER,
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-gender-freq.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)
    
lastName_attr = \
    generator.GenerateFreqAttribute(
        attribute_name=ATTR_LAST_NAME,
        freq_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/family-name-freq.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)
    
date_of_birth_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_DOB,
        function=attrgenfunct.generate_date_of_birth)
    
city_attr = \
    generator.GenerateFreqAttribute(
         attribute_name=ATTR_CITY,
         freq_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/city-freq.csv',
         has_header_line=False,
         unicode_encoding=unicode_encoding_used)

phone_num_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_PHONE_NUMBER,
        function=attrgenfunct.generate_phone_number_ethiopia)

national_id_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_NATIONAL_ID,
        function=attrgenfunct.generate_national_id_number)


# -----------------------------------------------------------------------------
# Define how the generated records are to be corrupted (using methods from
# the corruptor.py module).

# For a value edit corruptor, the sum or the four probabilities given must
# be 1.0.
#
edit_corruptor = \
    corruptor.CorruptValueEdit(
        position_function=corruptor.position_mod_normal,
        char_set_funct=basefunctions.char_set_ascii,
        insert_prob=0.5,
        delete_prob=0.5,
        substitute_prob=0.0,
        transpose_prob=0.0)

edit_corruptor2 = \
    corruptor.CorruptValueEdit(
        position_function=corruptor.position_mod_uniform,
        char_set_funct=basefunctions.char_set_ascii,
        insert_prob=0.25,
        delete_prob=0.25,
        substitute_prob=0.25,
        transpose_prob=0.25)

name_misspell_corruptor = \
    corruptor.CorruptCategoricalValue(
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-misspell.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)

name_m_misspell_corruptor = \
    corruptor.CorruptCategoricalValue(
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-m-misspell.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)


ocr_corruptor = corruptor.CorruptValueOCR(
    position_function=corruptor.position_mod_normal,
    lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/ocr-variations.csv',
    has_header_line=False,
    unicode_encoding=unicode_encoding_used)

keyboard_corruptor = corruptor.CorruptValueKeyboard(
    position_function=corruptor.position_mod_normal,
    row_prob=0.5,
    col_prob=0.5)

phonetic_corruptor = corruptor.CorruptValuePhonetic(
    lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/phonetic-variations.csv',
    has_header_line=False,
    unicode_encoding=unicode_encoding_used)

missing_val_corruptor = corruptor.CorruptMissingValue()

# -----------------------------------------------------------------------------
# Define the attributes to be generated for this data set, and the data set
# itself.
#
attr_name_list = [ATTR_NAME,
                  ATTR_LAST_NAME,
                  ATTR_GENDER,
                  ATTR_DOB,
                  ATTR_CITY,
                  ATTR_PHONE_NUMBER,
                  ATTR_NATIONAL_ID
                 
                  ]

attr_data_list = [  name_gender_attr,
    lastName_attr,
    date_of_birth_attr,
    city_attr,
    phone_num_attr,
    national_id_attr,

    ]

# Nothing to change here - set-up the data set generation object.
#
test_data_generator = generator.GenerateDataSet(
    output_file_name=out_file_name,
    write_header_line=True,
    rec_id_attr_name=rec_id_attr_name,
    number_of_records=num_org_rec,
    attribute_name_list=attr_name_list,
    attribute_data_list=attr_data_list,
    unicode_encoding=unicode_encoding_used)

# Define the probability distribution of how likely an attribute will be
# selected for a modification.
# Each of the given probability values must be between 0 and 1, and the sum of
# them must be 1.0.
# If a probability is set to 0 for a certain attribute, then no modification
# will be applied on this attribute.
#
attr_mod_prob_dictionary = {
    ATTR_NAME: given_name_val,
    ATTR_LAST_NAME: family_name_val,
    ATTR_GENDER:gender_val,
    ATTR_DOB: dob_val,
    ATTR_CITY: city_val,
    ATTR_PHONE_NUMBER: pn_val,
    ATTR_NATIONAL_ID: nid_val,
    
    }


# Define the actual corruption (modification) methods that will be applied on
# the different attributes.
# For each attribute, the sum of probabilities given must sum to 1.0.
#
attr_mod_data_dictionary = {   
    ATTR_NATIONAL_ID: [(missing_val_NID, missing_val_corruptor),
                       (ocr_NID, ocr_corruptor),
                       (keyboard_NID, keyboard_corruptor)],
    ATTR_NAME: [(missing_val_FN, missing_val_corruptor),
                (name_misspell_FN, name_misspell_corruptor),
                (edit_FN, edit_corruptor2),
                (ocr_FN, ocr_corruptor),
                (keyboard_FN, keyboard_corruptor),
                (phonetic_FN, phonetic_corruptor)],
    ATTR_LAST_NAME: [(missing_val_LN, missing_val_corruptor),
                        (name_misspell_LN, name_m_misspell_corruptor),
                        (edit_LN, edit_corruptor2),
                        (ocr_LN, ocr_corruptor),
                        (keyboard_LN, keyboard_corruptor),
                        (phonetic_LN, phonetic_corruptor)],
    ATTR_GENDER: [(missing_val_GAB, missing_val_corruptor),
                  (ocr_GAB, ocr_corruptor),
                  (keyboard_GAB, keyboard_corruptor)],
    ATTR_DOB: [(missing_val_DOB, missing_val_corruptor),
               (keyboard_DOB, keyboard_corruptor)],
    ATTR_CITY: [(missing_val_C, missing_val_corruptor),
                (edit_C, edit_corruptor),
                (phonetic_C, phonetic_corruptor)],
    ATTR_PHONE_NUMBER: [(missing_val_PN, missing_val_corruptor),
                        (edit_PN, edit_corruptor2),
                        (keyboard_PN, keyboard_corruptor)]
   
}

# Nothing to change here - set-up the data set corruption object
#
test_data_corruptor = corruptor.CorruptDataSet(
    number_of_org_records=num_org_rec,
    number_of_mod_records=num_dup_rec,
    attribute_name_list=attr_name_list,
    max_num_dup_per_rec=max_duplicate_per_record,
    num_dup_dist=num_duplicates_distribution,
    max_num_mod_per_attr=max_modification_per_attr,
    num_mod_per_rec=num_modification_per_record,
    attr_mod_prob_dict=attr_mod_prob_dictionary,
    attr_mod_data_dict=attr_mod_data_dictionary)

# =============================================================================
# No need to change anything below here

# Start the data generation process
#
rec_dict = test_data_generator.generate()

# Check the number of generated records
assert len(rec_dict) == num_org_rec

# Corrupt (modify) the original records into duplicate records
#
rec_dict = test_data_corruptor.corrupt_records(rec_dict)

# Check total number of records
assert len(rec_dict) == num_org_rec + num_dup_rec

# Write generate data into a file
#
test_data_generator.write()

# End.
# =============================================================================
# Out:
# Generating 2 modified (duplicate) records for record "rec-00000751-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000839-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000897-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000812-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000185-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000546-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000910-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000531-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000012-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000140-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000214-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000826-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000764-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000848-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000029-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000653-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000674-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000951-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000513-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000460-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000190-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000875-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000522-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000935-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000814-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000799-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000568-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000171-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000569-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000228-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000237-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000868-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000365-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000473-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000621-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000558-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000033-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000118-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000548-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000002-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000301-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000236-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000319-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000448-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000801-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000805-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000686-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000880-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000644-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000283-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000953-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000322-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000372-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000923-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000821-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000160-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000137-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000679-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000888-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000662-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000565-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000544-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000811-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000326-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000701-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000543-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000038-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000126-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000798-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000519-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000810-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000158-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000495-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000466-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000422-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000224-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000741-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000919-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000572-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000788-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000916-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000202-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000418-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000499-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000276-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000132-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000208-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000046-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000505-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000971-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000313-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000762-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000574-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000914-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000552-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000988-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000020-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000934-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000989-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000133-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000771-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000375-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000192-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000661-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000395-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000320-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000828-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000098-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000678-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000071-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000630-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000625-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000381-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000717-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000696-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000835-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000470-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000837-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000611-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000252-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000725-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000706-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000818-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000512-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000260-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000300-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000065-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000907-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000996-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000614-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000999-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000366-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000263-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000902-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000151-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000196-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000040-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000455-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000746-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000386-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000535-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000680-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000394-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000168-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000876-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000635-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000269-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000742-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000315-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000179-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000195-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000591-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000261-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000688-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000831-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000857-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000484-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000333-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000631-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000006-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000178-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000712-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000665-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000976-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000292-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000478-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000143-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000541-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000774-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000890-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000494-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000113-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000475-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000616-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000655-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000748-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000110-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000044-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000452-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000483-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000280-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000577-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000213-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000138-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000603-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000732-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000977-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000832-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000446-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000037-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000256-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000287-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000870-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000436-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000416-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000944-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000458-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000362-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000719-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000279-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000289-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000317-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000093-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000318-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000018-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000102-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000511-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000355-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000026-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000918-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000050-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000072-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000415-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000267-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000715-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000968-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000111-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000163-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000698-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000120-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000383-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000948-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000121-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000660-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000986-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000627-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000752-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000332-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000508-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000266-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000882-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000041-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000733-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000433-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000652-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000754-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000667-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000736-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000579-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000056-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000385-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000895-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000800-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000180-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000453-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000555-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000672-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000233-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000671-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000842-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000666-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000729-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000563-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000025-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000958-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000442-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000411-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000599-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000308-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000410-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000589-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000651-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000768-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000966-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000234-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000295-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000309-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000274-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000057-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000695-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000123-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000744-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000426-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000100-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000217-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000710-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000232-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000427-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000166-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000991-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000469-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000367-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000973-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000244-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000763-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000149-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000585-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000281-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000687-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000265-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000479-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000739-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000055-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000357-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000517-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000909-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000743-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000777-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000082-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000825-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000879-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000297-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000440-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000714-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000087-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000288-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000099-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000683-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000929-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000863-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000945-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000294-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000364-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000791-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000338-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000623-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000984-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000516-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000518-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000095-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000529-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000779-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000251-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000358-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000142-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000685-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000566-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000229-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000594-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000398-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000091-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000048-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000340-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000148-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000139-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000189-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000682-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000750-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000439-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000226-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000384-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000454-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000314-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000930-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000175-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000028-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000823-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000064-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000536-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000647-aaa-0"
#
# Generating 1 modified (duplicate) records for record "rec-00000596-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000502-aaa-0"

# %%
#@title <font color="#18CF68">View Generated Data
data =pd.read_csv(out_file_name)
display(data)
# Out:
#                       ID Given Name  ...  Phone Number      National ID
# 0     rec-00000000-aaa-0     Samwel  ...  046-258-8750  200403116015435
# 1     rec-00000001-aaa-0        Ann  ...  011-654-3026  200011278724128
# 2     rec-00000002-aaa-0     Nafula  ...  022-519-9225  199610089352503
# 3     rec-00000002-bbb-0     Nafula  ...  022-519-9225  199610089352503
# 4     rec-00000002-bbb-1     Nafuja  ...  022-519-9225  199610089252503
# ...                  ...        ...  ...           ...              ...
# 1495  rec-00000996-bbb-0  Wanyonyai  ...  011-111-3244  200102031515192
# 1496  rec-00000997-aaa-0   Nasimiyu  ...  091-499-9348  199303287035535
# 1497  rec-00000998-aaa-0      Diana  ...  091-181-9020  199709260761519
# 1498  rec-00000999-aaa-0     Mathew  ...  091-711-9213  199905259624478
# 1499  rec-00000999-bbb-0     Mathe3  ...  091-711-9213  19990525g624478
#
# [1500 rows x 8 columns]

# %% [markdown]
# ## **<font color="#007f68"> 5) Results**

# %% [markdown]
# ### <font color="#007f68"> Save the generated data to your Google Drive
#
# Ensure you have mounted your drive Given at step 3

# %%
#@title <font color="#18CF68">Enter file path to desired destination for generated data 
file_path = "/content/drive/MyDrive/Data Generator" #@param {type:"string"}

# %%
#@title <font color="#18CF68">Copy output file to drive
shutil.copy(out_file_name, file_path)
# Out:
# '/content/drive/MyDrive/Data Generator/data-30000-15000.csv'

# %% [markdown]
# ### <font color="#007f68">  Download the Generated Data

# %%
#@title <font color="#18CF68">Download the Generated Data
files.download(out_file_name)
