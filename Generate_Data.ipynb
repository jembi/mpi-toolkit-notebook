# %% [markdown]
# <a href="https://colab.research.google.com/github/jembi/mpi-toolkit-notebook/blob/main/Generate_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 📝 NOTE: Please do not execute a run all command.

# %% [markdown]
# #1) Clone the github Data Generator Repo & Initial imports

# %%
#@title Clone the github Data Generator Repo from Github
# !git clone https://github.com/jembi/mpi-toolkit-notebook.git
# Out:
# Cloning into 'mpi-toolkit-notebook'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 96 (delta 38), reused 42 (delta 8), pack-reused 0
# Unpacking objects: 100% (96/96), done.

# %%
#@title Initial imports
import pandas as pd
import os
import sys
import shutil
from google.colab import files
# %load_ext google.colab.data_table
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table

# %% [markdown]
# #2.1) View Frequency Distribution Files

# %% [markdown]
# This sections allows you to view the current lookup tables and replace then with your own csv files

# %%
#@title Display City Frequency
country_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/country-freq.csv", header=None)
display(country_freq)
# Out:
#              0   1
# 0     Ethiopia  70
# 1        Sudan  10
# 2  South Sudan   5
# 3      Somalia  10
# 4      Eritrea   5

# %%
#@title Display First Name & Gender Frequency
name_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-freq.csv", header=None)
display(name_freq)
# Out:
#               0  1       2  3
# 0         Sisay  8  female  1
# 1       Meseret  7  female  1
# 2       Habtamu  7  female  1
# 3     Selamawit  7  female  1
# 4         Helen  6  female  1
# ...         ... ..     ... ..
# 1565    Zewolde  1    male  1
# 1566    Zewudie  1    male  1
# 1567     Zewudu  1    male  1
# 1568      Zinab  1    male  1
# 1569      Zurga  1    male  1
#
# [1570 rows x 4 columns]

# %%
#@title Display Last Name Frequency
name_m_freq =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-m-freq.csv", header=None)
display(name_m_freq)
# Out:
#              0   1
# 0     Mohammed  26
# 1      Tesfaye  26
# 2        Hailu  23
# 3      Tadesse  21
# 4       Kebede  20
# ...        ...  ..
# 1271   Zewolde   1
# 1272   Zewudie   1
# 1273    Zewudu   1
# 1274     Zinab   1
# 1275     Zurga   1
#
# [1276 rows x 2 columns]

# %% [markdown]
# #2.2) Update Frequency Distribution Files
# ⚠️ *WARNING! DO NOT RUN IF YOU ARE NOT CHANGING CSV FILES* ⚠️

# %% [markdown]
# ##Replace the City Frequency file

# %% [markdown]
# Run the cell below and choose the Country Frequency CSV file you want to use. The cells that follow will replace the original file with the one you upload.

# %%
#@title Download City Frequency file
files.download(country_freq)

# %%
#@title Upload Last Name Frequency file
uploadCF = files.upload()

# %%
#@title Prepare file
x =uploadCF.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

# %%
#@title Rename file
os.rename(z , "/content/country-freq.csv")

# %%
#@title Remove old file
! rm "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/country-freq.csv"

# %%
#@title Move file to correct location
shutil.move("/content/country-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
# ##Replace the First Name Frequency file

# %% [markdown]
# Run the cell below and choose the First Name Frequency CSV file you want to use. The cells that follow will replace the original file with the one you upload.

# %%
#@title Download First Name Frequency file
files.download(name_freq)

# %%
#@title Upload First Name Frequency file
uploadFN = files.upload()

# %%
#@title Prepare file
x =uploadFN.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

# %%
#@title Rename file
os.rename(z , "/content/given-name-freq.csv")

# %%
#@title Remove old file
! rm "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-freq.csv"

# %%
#@title Move file to correct location
shutil.move("/content/given-name-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
# ##Replace the Last Name Frequency table

# %% [markdown]
# Run the cell below and choose the Last Name Frequency CSV file you want to use. The cells that follow will replace the original file with the one you upload.

# %%
#@title Download Last Name Frequency file
files.download(name_m_freq)

# %%
#@title Upload Last Name Frequency file
uploadLN = files.upload()

# %%
#@title Prepare file
x =uploadLN.keys()
y = str(x)
z=y.strip("dict_keys([").strip("])").strip("'")

# %%
#@title Rename file
os.rename(z , "/content/gname-m-freq.csv")

# %%
#@title Remove old file
! rm "/content/mpi-toolkit-notebook/data-generator/lookup-files/GECO-Kenya/name-m-freq.csv"

# %%
#@title Move file to correct location
shutil.move("/content/name-m-freq.csv", "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files")

# %% [markdown]
# #*Not sure if needed*

# %%
town_alt_name =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/lookup-files/town-alt-name.csv")
display(town_alt_name)
# Out:
#       Addis Ababa    Adis Ababa
# 0          Gondar        Gonder
# 1           Adama        Nazret
# 2           Awasa       Hawassa
# 3       Dire Dawa     Dire Dewa
# 4          Dessie         Desie
# ..            ...           ...
# 61         Gewana        Gewane
# 62         Werder        Warder
# 63           Sire         Sirie
# 64   Shek Hussein       Anajina
# 65  Tinsae Berhan  Tinsaeberhan
#
# [66 rows x 2 columns]

# %%
town_region_2 =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/town-region-2.csv")
display(town_region_2)
# Out:
#         Tahtay Adiyabo   77333  Tigray  1
# 0        Laelay Adiabo   37017  Tigray  1
# 1                 Zana   69755  Tigray  1
# 2        Tahtay Koraro   91466  Tigray  1
# 3               Asgede  104407  Tigray  1
# 4             Tselemti  128532  Tigray  1
# ...                ...     ...     ... ..
# 1035            Darara  124439  Sidama  1
# 1036            Daella   40600  Sidama  1
# 1037        Chuko town   37201  Sidama  1
# 1038  Wondo-Genet town   56414  Sidama  1
# 1039        Loka Abaya  109526  Sidama  1
#
# [1040 rows x 4 columns]

# %%
town_region =pd.read_csv("/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/town-region.csv")
display(town_region)
# Out:
#        Addis Ababa  ...  1
# 0           Gondar  ...  1
# 1           Mekele  ...  1
# 2            Adama  ...  1
# 3            Awasa  ...  1
# 4        Bahir Dar  ...  1
# ..             ...  ... ..
# 174   Shek Hussein  ...  1
# 175        Amanuel  ...  1
# 176  Tinsae Berhan  ...  1
# 177        Langano  ...  1
# 178       Erta Ale  ...  1
#
# [179 rows x 4 columns]

# %% [markdown]
# #3) Mount Drive
#
# Follow the link to get authorisation code.

# %% [markdown]
# Mounting your google drive will allow you to save the generated data directly to your drive.
#
# *If you would prefer to dowload your data- you may skip this step*

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #4) Create file path to allow for imports and import necessary classes

# %%
#@title Create file path
py_file_location = "/content/mpi-toolkit-notebook/data-generator/GECO-Kenya"
sys.path.append(os.path.abspath(py_file_location))

# %%
#@title Import Classes
import random

import attrgenfunct  # Functions to generate independent attribute values
# Import the necessary other modules of the data generator
#
import basefunctions  # Helper functions
import corruptor  # Main classes to corrupt attribute values and records
import generator  # Main classes to generate records and the data set
import output       # Main classes to output logs to a .txt file

random.seed(42)  # Set seed for random generator, so data generation can
#                       be repeated

# %% [markdown]
# #5.1) Set Variables to Default

# %% [markdown]
# Run this section if you would like to execute the data generator under default conditions (and skip the next section).

# %%
#@title Data Generator Variables

max_duplicate_per_record =  2 

num_duplicates_distribution = 'zipf' 

max_modification_per_attr = 1 

num_modification_per_record = 4 

#First Name Corruptor

missing_val_FN = 0.1 
name_misspell_FN = 0.1 
edit_FN = 0.1 
ocr_FN = 0.1 
keyboard_FN = 0.1 
phonetic_FN = 0.5 

#Last Name Corruptor

missing_val_LN = 0.1 
name_misspell_LN = 0.1 
edit_LN = 0.1 
ocr_LN = 0.1 
keyboard_LN = 0.1 
phonetic_LN = 0.5 

#Gender at Birth Corruptor

missing_val_GAB = 0.2 
ocr_GAB = 0.4 
keyboard_GAB = 0.4

#Date of Birth Corruptor

missing_val_DOB = 0.5 
keyboard_DOB = 0.5 

#City Corruptor

missing_val_C = 0.2 
edit_C = 0.4 
phonetic_C = 0.4 


#Phone Number Corruptor

missing_val_PN = 0.2 
edit_PN = 0.4 
keyboard_PN = 0.4

#National ID Corruptor

missing_val_NID = 0.4 
ocr_NID = 0.2 
keyboard_NID = 0.4

# %% [markdown]
# #5.2) Define Variables

# %% [markdown]
# Run this section if you would like to execute the data generator under user defied conditions (and skip the previous section).

# %%
#@title Data Generator Parameters
max_duplicate_per_record =  2 #@param {type:"slider", min:0, max:10, step:1}

num_duplicates_distribution = 'zipf' #@param ["zipf", "poisson", "uniform"] 

max_modification_per_attr = 1 #@param {type:"slider", min:0, max:10, step:1}

num_modification_per_record = 4 #@param {type:"slider", min:0, max:100, step:1}

# %% [markdown]
# ⚠️ *WARNING make sure the values below do not exceed a total of 1* ⚠️

# %%
 #@title First Name Corruptors

missing_val_FN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
name_misspell_FN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
edit_FN = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
ocr_FN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_FN = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
phonetic_FN = 0.3 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
#@title Last Name Corruptors
missing_val_LN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
name_misspell_LN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
edit_LN = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
ocr_LN = 0.1 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_LN = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
phonetic_LN = 0.3 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
#@title Gender at Birth Corruptors
missing_val_GAB = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}
ocr_GAB = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_GAB = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
#@title Date of Birth Corruptors
missing_val_DOB = 0.6 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_DOB = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
#@title City Corruptors
missing_val_C = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
edit_C = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}
phonetic_C = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
 #@title Phone Number Corruptors
missing_val_PN = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
edit_PN = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_PN = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}

# %%
#@title National ID Corruptors
missing_val_NID = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}
ocr_NID = 0.2 #@param {type:"slider", min:0, max:1, step:0.1}
keyboard_NID = 0.4 #@param {type:"slider", min:0, max:1, step:0.1}

# %% [markdown]
# #6.1) Set Input

# %% [markdown]
# Input the number of original records and duplicate records you want the data generator to produce.

# %%
number_of_originals =  1900 #@param {type:"slider", min:0, max:30000, step:50}
number_of_duplicates =  3275 #@param {type:"slider", min:0, max:15000, step:25}

# %% [markdown]
# #6.2) Run the Data Generator & Display results

# %%
#@title Run Data Generator

#args = sys.argv[1:]
output.create_file()

#if len(args) != 3:
#    print(f"usage python Generate-Data.ipynb 1000 500 data-1000-500.csv")
#    exit(-1)

ATTR_NAME = "First Name"  # IN
ATTR_LAST_NAME = "Last Name"  # IN
ATTR_GENDER = "Gender at Birth"  # IN
#ATTR_GENDER_AT_BIRTH = "genderAtBirth"  # IN
ATTR_DOB = "Date of Birth"  # IN
ATTR_CITY = "City"  # IN
#ATTR_TOWN = "town"  # IN
ATTR_PHONE_NUMBER = "Phone Number"  # IN [optional]
ATTR_NATIONAL_ID = "National ID"  # IN [optional]

#ATTR_FATHERS_NAME = "fathersName"  # IN
#ATTR_FATHERS_FATHER_NAME = "fathersFatherName"  # IN
#ATTR_MOTHERS_NAME = "mothersName"  # IN
#ATTR_MOTHERS_FATHER_NAME = "mothersFatherName"  # IN

# ATTR_COUNTRY = "country"  # IN
# ATTR_STATE = "state"
#ATTR_DISTRICT = "district"  # IN


# ATTR_REG_ID = "registration_id"  # IN
# ATTR_REG_FACILITY_CODE = "registration_facility_code"  # IN
#ATTR_ENROLLMENT_HIV_ID = "hivCaseReportNumber"
# ATTR_ENROLLMENT_FACILITY_CODE = "enrollment_hiv_facility_code"


# Set the Unicode encoding for this data generation project. This needs to be
# changed to another encoding for different Unicode character sets.
# Valid encoding strings are listed here:
# http://docs.python.org/library/codecs.html#standard-encodings
#
unicode_encoding_used = 'ascii'

# The name of the record identifier attribute (unique value for each record).
# This name cannot be given as name to any other attribute that is generated.
#
rec_id_attr_name = 'ID'

# Set how many original and how many duplicate records are to be generated.
#

num_org_rec = int(number_of_originals)
num_dup_rec = int(number_of_duplicates)

# Set the file name of the data set to be generated (this will be a comma
# separated values, CSV, file).
#
out_file_name = 'data-{}-{}.csv'.format(num_org_rec, num_dup_rec)
#out_file_name = args[2]

# Set the file name of the data set to be generated (this will be
# Set the maximum number of duplicate records can be generated per original
# record.
#

#Defined above
#max_duplicate_per_record =  2 


# Set the probability distribution used to create the duplicate records for one
# original record (possible values are: 'uniform', 'poisson', 'zipf').
#
#Defined above
#num_duplicates_distribution = 'zipf' 


# Set the maximum number of modification that can be applied to a single
# attribute (field).
#

#Defined above
#max_modification_per_attr = 1 

# Set the number of modification that are to be applied to a record.
#

#Defined above
#num_modification_per_record = 4 

# Check if the given the unicode encoding selected is valid.
#
basefunctions.check_unicode_encoding_exists(unicode_encoding_used)

# -----------------------------------------------------------------------------
# Define the attributes to be generated (using methods from the generator.py
# module).
#


name_gender_attr = \
    generator.GenerateCateCateCompoundAttribute(
        categorical1_attribute_name=ATTR_NAME,
        categorical2_attribute_name=ATTR_GENDER,
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/given-name-freq.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)
    
lastName_attr = \
    generator.GenerateFreqAttribute(
        attribute_name=ATTR_LAST_NAME,
        freq_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-m-freq.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)
    
date_of_birth_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_DOB,
        function=attrgenfunct.generate_date_of_birth)
    
city_attr = \
    generator.GenerateFreqAttribute(
         attribute_name=ATTR_CITY,
         freq_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/country-freq.csv',
         has_header_line=False,
         unicode_encoding=unicode_encoding_used)

phone_num_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_PHONE_NUMBER,
        function=attrgenfunct.generate_phone_number_ethiopia)

national_id_attr = \
    generator.GenerateFuncAttribute(
        attribute_name=ATTR_NATIONAL_ID,
        function=attrgenfunct.generate_national_id_number)
#fathersName_attr = \
#    generator.GenerateFreqAttribute(
#        attribute_name=ATTR_FATHERS_NAME,
#        freq_file_name='lookup-files/name-m-freq.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)

#fathersFatherName_attr = \
#    generator.GenerateFreqAttribute(
#        attribute_name=ATTR_FATHERS_FATHER_NAME,
#        freq_file_name='lookup-files/name-m-freq.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)
#mothersName_attr = \
#    generator.GenerateFreqAttribute(
#        attribute_name=ATTR_MOTHERS_NAME,
#        freq_file_name='lookup-files/name-m-freq.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)
#mothersFatherName_attr = \
#    generator.GenerateFreqAttribute(
#        attribute_name=ATTR_MOTHERS_FATHER_NAME,
#        freq_file_name='lookup-files/name-m-freq.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)

# avonym_attr = \
#    generator.GenerateFreqAttribute(
#        attribute_name='Avonym',
#        freq_file_name='lookup-files/name-m-freq.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)
    
#town_district_attr = \
#    generator.GenerateCateCateCompoundAttribute(
#        categorical1_attribute_name=ATTR_TOWN,
#        categorical2_attribute_name=ATTR_DISTRICT,
#        lookup_file_name='lookup-files/town-region-2.csv',
#        has_header_line=False,
#        unicode_encoding=unicode_encoding_used)

# country_attr = \
#     generator.GenerateFreqAttribute(
#         attribute_name=ATTR_COUNTRY,
#         freq_file_name='lookup-files/country-freq.csv',
#         has_header_line=False,
#         unicode_encoding=unicode_encoding_used)

# registration_id_attr =  \
#     generator.GenerateFuncAttribute(
#         attribute_name=ATTR_REG_ID,
#         function=attrgenfunct.generate_client_registration_id)

# registration_facility_code_attr =  \
#     generator.GenerateFuncAttribute(
#         attribute_name=ATTR_REG_FACILITY_CODE,
#         function=attrgenfunct.generate_client_registration_facility_code)

#enrollment_hiv_id_attr = \
#    generator.GenerateFuncAttribute(
#        attribute_name=ATTR_ENROLLMENT_HIV_ID,
#        function=attrgenfunct.generate_enrollment_hiv_id)

# enrollment_hiv_facility_code_attr = \
#     generator.GenerateFuncAttribute(
#         attribute_name=ATTR_ENROLLMENT_FACILITY_CODE,
#         function=attrgenfunct.generate_enrollment_hiv_facility_code)

         


# -----------------------------------------------------------------------------
# Define how the generated records are to be corrupted (using methods from
# the corruptor.py module).

# For a value edit corruptor, the sum or the four probabilities given must
# be 1.0.
#
edit_corruptor = \
    corruptor.CorruptValueEdit(
        position_function=corruptor.position_mod_normal,
        char_set_funct=basefunctions.char_set_ascii,
        insert_prob=0.5,
        delete_prob=0.5,
        substitute_prob=0.0,
        transpose_prob=0.0)

edit_corruptor2 = \
    corruptor.CorruptValueEdit(
        position_function=corruptor.position_mod_uniform,
        char_set_funct=basefunctions.char_set_ascii,
        insert_prob=0.25,
        delete_prob=0.25,
        substitute_prob=0.25,
        transpose_prob=0.25)

name_misspell_corruptor = \
    corruptor.CorruptCategoricalValue(
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-misspell.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)

name_m_misspell_corruptor = \
    corruptor.CorruptCategoricalValue(
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/name-m-misspell.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)

town_alt_name_corruptor = \
    corruptor.CorruptCategoricalValue(
        lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/town-alt-name.csv',
        has_header_line=False,
        unicode_encoding=unicode_encoding_used)

ocr_corruptor = corruptor.CorruptValueOCR(
    position_function=corruptor.position_mod_normal,
    lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/ocr-variations.csv',
    has_header_line=False,
    unicode_encoding=unicode_encoding_used)

keyboard_corruptor = corruptor.CorruptValueKeyboard(
    position_function=corruptor.position_mod_normal,
    row_prob=0.5,
    col_prob=0.5)

phonetic_corruptor = corruptor.CorruptValuePhonetic(
    lookup_file_name='/content/mpi-toolkit-notebook/data-generator/GECO-Kenya/lookup-files/phonetic-variations.csv',
    has_header_line=False,
    unicode_encoding=unicode_encoding_used)

missing_val_corruptor = corruptor.CorruptMissingValue()

# -----------------------------------------------------------------------------
# Define the attributes to be generated for this data set, and the data set
# itself.
#
attr_name_list = [ATTR_NAME,
                  ATTR_LAST_NAME,
                  ATTR_GENDER,
                  ATTR_DOB,
                  ATTR_CITY,
                  ATTR_PHONE_NUMBER,
                  ATTR_NATIONAL_ID
                  
                  #ATTR_ENROLLMENT_HIV_ID,
                  #ATTR_FATHERS_NAME,
                  #ATTR_FATHERS_FATHER_NAME,
                  #ATTR_MOTHERS_NAME,
                  #ATTR_MOTHERS_FATHER_NAME,
                  #   ATTR_COUNTRY,
                  #ATTR_DISTRICT,
                  #ATTR_TOWN
                  #   ATTR_REG_ID,
                  #   ATTR_REG_FACILITY_CODE,
                  #   ATTR_ENROLLMENT_FACILITY_CODE,
                  ]

attr_data_list = [  name_gender_attr,
    lastName_attr,
    date_of_birth_attr,
    city_attr,
    phone_num_attr,
    national_id_attr,
    #fathersName_attr,
    #fathersFatherName_attr,
    #mothersName_attr,
    #mothersFatherName_attr,
    #   country_attr,
    #town_district_attr,
    #   registration_id_attr,
    #   registration_facility_code_attr,
    #   enrollment_hiv_facility_code_attr,
    #enrollment_hiv_id_attr
    ]

# Nothing to change here - set-up the data set generation object.
#
test_data_generator = generator.GenerateDataSet(
    output_file_name=out_file_name,
    write_header_line=True,
    rec_id_attr_name=rec_id_attr_name,
    number_of_records=num_org_rec,
    attribute_name_list=attr_name_list,
    attribute_data_list=attr_data_list,
    unicode_encoding=unicode_encoding_used)

# Define the probability distribution of how likely an attribute will be
# selected for a modification.
# Each of the given probability values must be between 0 and 1, and the sum of
# them must be 1.0.
# If a probability is set to 0 for a certain attribute, then no modification
# will be applied on this attribute.
#
attr_mod_prob_dictionary = {
    ATTR_NAME: 0.22,
    ATTR_LAST_NAME: 0.16,
    #ATTR_GENDER_AT_BIRTH: 0.08,
    ATTR_GENDER:0.08,
    ATTR_DOB: 0.19,
    ATTR_CITY: 0.09,
    ATTR_PHONE_NUMBER: 0.07,
    ATTR_NATIONAL_ID: 0.19,
    
    #ATTR_FATHERS_NAME: 0.11,
    #ATTR_FATHERS_FATHER_NAME: 0.10,
    #ATTR_MOTHERS_NAME: 0.10,
    #ATTR_MOTHERS_FATHER_NAME: 0.09,
    #ATTR_GENDER: 0.08,
    #ATTR_DISTRICT: 0.08,
    #ATTR_TOWN: 0.09,
    # ATTR_COUNTRY: 0.07,
    # ATTR_REG_ID: 0.07,
    # ATTR_REG_FACILITY_CODE: 0.07,
    # ATTR_ENROLLMENT_FACILITY_CODE: 0.07,
    #ATTR_ENROLLMENT_HIV_ID: 0.07
    }

# Define the actual corruption (modification) methods that will be applied on
# the different attributes.
# For each attribute, the sum of probabilities given must sum to 1.0.
#
attr_mod_data_dictionary = {   
    ATTR_NATIONAL_ID: [(missing_val_NID, missing_val_corruptor),
                       (ocr_NID, ocr_corruptor),
                       (keyboard_NID, keyboard_corruptor)],
    ATTR_NAME: [(missing_val_FN, missing_val_corruptor),
                (name_misspell_FN, name_misspell_corruptor),
                (edit_FN, edit_corruptor2),
                (ocr_FN, ocr_corruptor),
                (keyboard_FN, keyboard_corruptor),
                (phonetic_FN, phonetic_corruptor)],
    ATTR_LAST_NAME: [(missing_val_LN, missing_val_corruptor),
                        (name_misspell_LN, name_m_misspell_corruptor),
                        (edit_LN, edit_corruptor2),
                        (ocr_LN, ocr_corruptor),
                        (keyboard_LN, keyboard_corruptor),
                        (phonetic_LN, phonetic_corruptor)],
    ATTR_GENDER: [(missing_val_GAB, missing_val_corruptor),
                  (ocr_GAB, ocr_corruptor),
                  (keyboard_GAB, keyboard_corruptor)],
    ATTR_DOB: [(missing_val_DOB, missing_val_corruptor),
               (keyboard_DOB, keyboard_corruptor)],
    ATTR_CITY: [(missing_val_C, missing_val_corruptor),
                (edit_C, edit_corruptor),
                (phonetic_C, phonetic_corruptor)],
    ATTR_PHONE_NUMBER: [(missing_val_PN, missing_val_corruptor),
                        (edit_PN, edit_corruptor2),
                        (keyboard_PN, keyboard_corruptor)]

    #ATTR_FATHERS_NAME: [(0.1, missing_val_corruptor),
    #                    (0.1, name_m_misspell_corruptor),
    #                    (0.1, edit_corruptor2),
    #                    (0.1, ocr_corruptor),
    #                    (0.1, keyboard_corruptor),
    #                    (0.5, phonetic_corruptor)],
    #ATTR_FATHERS_FATHER_NAME: [(0.1, missing_val_corruptor),
    #                           (0.1, name_m_misspell_corruptor),
    #                           (0.1, edit_corruptor2),
    #                           (0.1, ocr_corruptor),
    #                           (0.1, keyboard_corruptor),
    #                           (0.5, phonetic_corruptor)],
    #ATTR_MOTHERS_NAME: [(0.1, missing_val_corruptor),
    #                    (0.1, name_m_misspell_corruptor),
    #                    (0.1, edit_corruptor2),
    #                    (0.1, ocr_corruptor),
    #                    (0.1, keyboard_corruptor),
    #                    (0.5, phonetic_corruptor)],
    #ATTR_MOTHERS_FATHER_NAME: [(0.1, missing_val_corruptor),
    #                           (0.1, name_m_misspell_corruptor),
    #                           (0.1, edit_corruptor2),
    #                           (0.1, ocr_corruptor),
    #                           (0.1, keyboard_corruptor),
    #                           (0.5, phonetic_corruptor)],
    #ATTR_GENDER_AT_BIRT: [(0.2, missing_val_corruptor),
    #              (0.4, ocr_corruptor),
    #              (0.4, keyboard_corruptor)],
    #ATTR_DISTRICT: [(0.1, missing_val_corruptor),
    #                (0.4, ocr_corruptor),
    #                (0.5, edit_corruptor)],
    # ATTR_COUNTRY: [(0.2, missing_val_corruptor),
    #                (0.4, edit_corruptor),
    #                (0.4, phonetic_corruptor)],
    #ATTR_TOWN: [(0.2, missing_val_corruptor),
    #            (0.1, ocr_corruptor),
    #            (0.5, keyboard_corruptor),
    #            (0.2, town_alt_name_corruptor)],
    # ATTR_REG_ID: [(0.1, missing_val_corruptor),
    #               (0.45, ocr_corruptor),
    #               (0.45, keyboard_corruptor)],
    # ATTR_REG_FACILITY_CODE: [(0.1, missing_val_corruptor),
    #                          (0.2, ocr_corruptor),
    #                          (0.7, keyboard_corruptor)],
    # ATTR_ENROLLMENT_FACILITY_CODE: [(0.4, missing_val_corruptor),
    #                                 (0.2, ocr_corruptor),
    #                                 (0.4, keyboard_corruptor)],
    #ATTR_ENROLLMENT_HIV_ID: [(0.4, missing_val_corruptor),
    #                         (0.2, ocr_corruptor),
    #                         (0.4, keyboard_corruptor)]
}

# Nothing to change here - set-up the data set corruption object
#
test_data_corruptor = corruptor.CorruptDataSet(
    number_of_org_records=num_org_rec,
    number_of_mod_records=num_dup_rec,
    attribute_name_list=attr_name_list,
    max_num_dup_per_rec=max_duplicate_per_record,
    num_dup_dist=num_duplicates_distribution,
    max_num_mod_per_attr=max_modification_per_attr,
    num_mod_per_rec=num_modification_per_record,
    attr_mod_prob_dict=attr_mod_prob_dictionary,
    attr_mod_data_dict=attr_mod_data_dictionary)

# =============================================================================
# No need to change anything below here

# Start the data generation process
#
rec_dict = test_data_generator.generate()

# Check the number of generated records
assert len(rec_dict) == num_org_rec

# Corrupt (modify) the original records into duplicate records
#
rec_dict = test_data_corruptor.corrupt_records(rec_dict)

# Check total number of records
assert len(rec_dict) == num_org_rec + num_dup_rec

# Write generate data into a file
#
test_data_generator.write()

# End.
# =============================================================================
# Out:
# Generating 2 modified (duplicate) records for record "rec-00000014-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000032-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000004-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000037-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000048-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000012-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000041-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000000-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000008-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000047-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000002-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000003-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000010-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000028-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000027-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000018-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000039-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000019-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000029-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000049-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000038-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000015-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000043-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000045-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000025-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000024-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000005-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000016-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000042-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000006-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000030-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000001-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000026-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000040-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000013-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000007-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000044-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000022-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000017-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000021-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000035-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000023-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000046-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000034-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000020-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000033-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000009-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000011-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000031-aaa-0"
#
# Generating 2 modified (duplicate) records for record "rec-00000036-aaa-0"

# %%
#@title View Generated Data
data =pd.read_csv(out_file_name)
display(data)
# Out:
#                      ID   First Name  ...  Phone Number      National ID
# 0    rec-00000000-aaa-0        Genet  ...  046-814-2954  200505038177449
# 1    rec-00000000-bbb-0        Genrt  ...  046-914-2954              NaN
# 2    rec-00000000-bbb-1         Gnet  ...  046-814-2954  200505038177449
# 3    rec-00000001-aaa-0         Teje  ...  011-434-7308  200407287455769
# 4    rec-00000001-bbb-0         Teie  ...  011-434-7308  200407287455769
# ..                  ...          ...  ...           ...              ...
# 145  rec-00000048-bbb-0      Mesered  ...  011-651-3543  199404106656449
# 146  rec-00000048-bbb-1     Mesteret  ...           NaN  1994041066564r9
# 147  rec-00000049-aaa-0  Gebremeskel  ...  091-739-9045  199710077670431
# 148  rec-00000049-bbb-0  Gebremeskel  ...  091-739-9045              NaN
# 149  rec-00000049-bbb-1  Gebremeskel  ...  091-739-9045  199710077670331
#
# [150 rows x 8 columns]

# %% [markdown]
# #7.1) Save the generated data to your Google Drive
#
# Ensure you have mounted your drive first at step 3

# %%
#@title Enter file path to desired destination for generated data 
file_path = "/content/drive/MyDrive/Data Generator" #@param {type:"string"}

# %%
#@title Copy Output file to drive
shutil.copy(out_file_name, file_path)
# Out:
# '/content/drive/MyDrive/Data Generator/data-50-100.csv'

# %% [markdown]
# #7.2) Download the Generated Data

# %%
#@title Download the Generated Data
files.download(out_file_name)
